# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 635

# %%
# Perform a weather check on each city using a series of successive API calls.
cities_df = pd.DataFrame(cities, columns=["City"])
cities_df["Lat"] = ''
cities_df["Lng"] = ''
cities_df["Max Temp"] = ''
cities_df["Humidity"] = ''
cities_df["Cloudiness"] = ''
cities_df["Wind Speed"] = ''
cities_df["Country"] = ''
cities_df["Date"] = ''

# %%
# Include a print log of each city as it'sbeing processed (with the city number and city name).
for index, row in cities_df.iterrows():
    target_city = row['City']
    url = f"http://api.openweathermap.org/data/2.5/weather?q={target_city}&appid={weather_api_key}&units=imperial"
    results = requests.get(url).json()
    print(f"Retrieving Results for {target_city}.")
    try:
        cities_df.loc[index, "Lat"] = results['coord']['lat']
        cities_df.loc[index, "Lng"] = results['coord']['lon']
        cities_df.loc[index, "Max Temp"] = results['main']['temp_max']
        cities_df.loc[index, "Humidity"] = results['main']['humidity']
        cities_df.loc[index, "Cloudiness"] = results['clouds']['all']
        cities_df.loc[index, "Wind Speed"] = results['wind']['speed']
        cities_df.loc[index, "Country"] = results['sys']['country']
        cities_df.loc[index, "Date"] = results['dt']
    except (KeyError, IndexError):
        print("City not found. Skipping...")
# Out:
# Retrieving Results for chuy.
# Retrieving Results for vaini.
# Retrieving Results for dikson.
# Retrieving Results for provideniya.
# Retrieving Results for yellowknife.
# Retrieving Results for souillac.
# Retrieving Results for rio gallegos.
# Retrieving Results for bereda.
# Retrieving Results for deputatskiy.
# Retrieving Results for rikitea.
# Retrieving Results for nanortalik.
# Retrieving Results for camana.
# Retrieving Results for mataura.
# Retrieving Results for saint anthony.
# Retrieving Results for chokurdakh.
# Retrieving Results for salalah.
# Retrieving Results for port hardy.
# Retrieving Results for hilo.
# Retrieving Results for wynyard.
# Retrieving Results for norman wells.
# Retrieving Results for butaritari.
# Retrieving Results for komsomolskiy.
# Retrieving Results for okha.
# Retrieving Results for saint-jean-de-maurienne.
# Retrieving Results for east london.
# Retrieving Results for hermanus.
# Retrieving Results for ribeira grande.
# Retrieving Results for new norfolk.
# Retrieving Results for lagoa.
# Retrieving Results for kwekwe.
# Retrieving Results for conde.
# Retrieving Results for punta arenas.
# Retrieving Results for payo.
# Retrieving Results for shenjiamen.
# Retrieving Results for kisangani.
# Retrieving Results for khatanga.
# Retrieving Results for tuktoyaktuk.
# Retrieving Results for asau.
# Retrieving Results for faya.
# Retrieving Results for nha trang.
# Retrieving Results for jamestown.
# Retrieving Results for turukhansk.
# Retrieving Results for kodiak.
# Retrieving Results for belmonte.
# Retrieving Results for busselton.
# Retrieving Results for soc trang.
# Retrieving Results for luderitz.
# Retrieving Results for davila.
# Retrieving Results for port alfred.
# Retrieving Results for saskylakh.
# Retrieving Results for bredasdorp.
# Retrieving Results for poya.
# Retrieving Results for fortuna.
# Retrieving Results for leningradskiy.
# Retrieving Results for atuona.
# Retrieving Results for upernavik.
# Retrieving Results for hobart.
# Retrieving Results for cape town.
# Retrieving Results for carndonagh.
# Retrieving Results for dryden.
# Retrieving Results for barahona.
# Retrieving Results for visnes.
# Retrieving Results for coquimbo.
# Retrieving Results for henties bay.
# Retrieving Results for ponta do sol.
# Retrieving Results for eureka.
# Retrieving Results for velten.
# Retrieving Results for honiara.
# Retrieving Results for bilibino.
# Retrieving Results for airai.
# Retrieving Results for belaya gora.
# Retrieving Results for antalaha.
# Retrieving Results for san cristobal.
# Retrieving Results for ushuaia.
# Retrieving Results for mehamn.
# Retrieving Results for narsaq.
# Retrieving Results for bluff.
# Retrieving Results for ladario.
# Retrieving Results for codrington.
# Retrieving Results for sakakah.
# Retrieving Results for mahebourg.
# Retrieving Results for chicama.
# Retrieving Results for qaanaaq.
# Retrieving Results for albany.
# Retrieving Results for kamien pomorski.
# Retrieving Results for miles city.
# Retrieving Results for west wendover.
# Retrieving Results for zahesi.
# Retrieving Results for avarua.
# Retrieving Results for portland.
# Retrieving Results for arraial do cabo.
# Retrieving Results for lota.
# Retrieving Results for bathsheba.
# Retrieving Results for bengkulu.
# Retrieving Results for guerrero negro.
# Retrieving Results for kruisfontein.
# Retrieving Results for tanout.
# Retrieving Results for najran.
# Retrieving Results for nueva gerona.
# Retrieving Results for corinto.
# Retrieving Results for tiksi.
# Retrieving Results for namibe.
# Retrieving Results for alpena.
# Retrieving Results for san patricio.
# Retrieving Results for inuvik.
# Retrieving Results for lebu.
# Retrieving Results for tura.
# Retrieving Results for alofi.
# Retrieving Results for mataram.
# Retrieving Results for thompson.
# Retrieving Results for miri.
# Retrieving Results for sisimiut.
# Retrieving Results for victoria.
# Retrieving Results for ostrovnoy.
# Retrieving Results for saint-francois.
# Retrieving Results for melsungen.
# Retrieving Results for lasa.
# Retrieving Results for pijijiapan.
# Retrieving Results for borba.
# Retrieving Results for viedma.
# Retrieving Results for waterloo.
# Retrieving Results for carnarvon.
# Retrieving Results for cedar city.
# Retrieving Results for aljezur.
# Retrieving Results for san luis.
# Retrieving Results for cabo san lucas.
# Retrieving Results for port hedland.
# Retrieving Results for micheweni.
# Retrieving Results for mar del plata.
# Retrieving Results for haines junction.
# Retrieving Results for puerto ayora.
# Retrieving Results for kapaa.
# Retrieving Results for cao bang.
# Retrieving Results for panama city.
# Retrieving Results for pemangkat.
# Retrieving Results for andenes.
# Retrieving Results for bom jesus.
# Retrieving Results for praya.
# Retrieving Results for bialogard.
# Retrieving Results for nikolskoye.
# Retrieving Results for dana point.
# Retrieving Results for evans.
# Retrieving Results for west plains.
# Retrieving Results for ahipara.
# Retrieving Results for omboue.
# Retrieving Results for san lorenzo.
# Retrieving Results for cabatuan.
# Retrieving Results for inhambane.
# Retrieving Results for egvekinot.
# Retrieving Results for hithadhoo.
# Retrieving Results for tonj.
# Retrieving Results for saint george.
# Retrieving Results for puerto escondido.
# Retrieving Results for samarai.
# Retrieving Results for palana.
# Retrieving Results for miguel hidalgo.
# Retrieving Results for xining.
# Retrieving Results for staryy oskol.
# Retrieving Results for saint-philippe.
# Retrieving Results for ixtapa.
# Retrieving Results for letterkenny.
# Retrieving Results for nouadhibou.
# Retrieving Results for margate.
# Retrieving Results for kavieng.
# Retrieving Results for kristiinankaupunki.
# Retrieving Results for alyangula.
# Retrieving Results for sitka.
# Retrieving Results for havelock.
# Retrieving Results for barrow.
# Retrieving Results for bethel.
# Retrieving Results for dalmatovo.
# Retrieving Results for north bend.
# Retrieving Results for chico.
# Retrieving Results for sehwan.
# Retrieving Results for vila velha.
# Retrieving Results for soma.
# Retrieving Results for klaksvik.
# Retrieving Results for ketchikan.
# Retrieving Results for cockburn town.
# Retrieving Results for maniitsoq.
# Retrieving Results for evensk.
# Retrieving Results for arraias.
# Retrieving Results for sarankhola.
# Retrieving Results for dunedin.
# Retrieving Results for bonavista.
# Retrieving Results for zhangye.
# Retrieving Results for faanui.
# Retrieving Results for leshukonskoye.
# Retrieving Results for severo-kurilsk.
# Retrieving Results for carlos chagas.
# Retrieving Results for vila franca do campo.
# Retrieving Results for khani.
# Retrieving Results for panaba.
# Retrieving Results for aligudarz.
# Retrieving Results for frunze.
# Retrieving Results for sao joao da barra.
# Retrieving Results for arinos.
# Retrieving Results for qasigiannguit.
# Retrieving Results for porto tolle.
# Retrieving Results for mackay.
# Retrieving Results for palmaner.
# Retrieving Results for georgetown.
# Retrieving Results for pevek.
# Retrieving Results for flin flon.
# Retrieving Results for el tarra.
# Retrieving Results for ilulissat.
# Retrieving Results for urumqi.
# Retrieving Results for xichang.
# Retrieving Results for kirakira.
# Retrieving Results for port elizabeth.
# Retrieving Results for tulum.
# Retrieving Results for broken hill.
# Retrieving Results for sao filipe.
# Retrieving Results for iqaluit.
# Retrieving Results for yulara.
# Retrieving Results for weston.
# Retrieving Results for les cayes.
# Retrieving Results for synya.
# Retrieving Results for presidente epitacio.
# Retrieving Results for katsuura.
# Retrieving Results for siddipet.
# Retrieving Results for marzuq.
# Retrieving Results for bambous virieux.
# Retrieving Results for lebyazhye.
# Retrieving Results for mao.
# Retrieving Results for kargasok.
# Retrieving Results for nizwa.
# Retrieving Results for bismarck.
# Retrieving Results for nanakuli.
# Retrieving Results for sari.
# Retrieving Results for nata.
# Retrieving Results for umm lajj.
# Retrieving Results for anadyr.
# Retrieving Results for marsa matruh.
# Retrieving Results for cruzeiro do sul.
# Retrieving Results for mayna.
# Retrieving Results for sola.
# Retrieving Results for mau.
# Retrieving Results for sawtell.
# Retrieving Results for muravlenko.
# Retrieving Results for colac.
# Retrieving Results for aden.
# Retrieving Results for butte.
# Retrieving Results for korla.
# Retrieving Results for chalinze.
# Retrieving Results for bandarbeyla.
# Retrieving Results for kaitangata.
# Retrieving Results for kirkenes.
# Retrieving Results for kutum.
# Retrieving Results for pocone.
# Retrieving Results for havre-saint-pierre.
# Retrieving Results for naze.
# Retrieving Results for niquelandia.
# Retrieving Results for castro.
# Retrieving Results for lorengau.
# Retrieving Results for aquiraz.
# Retrieving Results for emerald.
# Retrieving Results for lethem.
# Retrieving Results for mount isa.
# Retrieving Results for myszkow.
# Retrieving Results for coihaique.
# Retrieving Results for torbay.
# Retrieving Results for khor.
# Retrieving Results for tautira.
# Retrieving Results for ust-nera.
# Retrieving Results for asfi.
# Retrieving Results for bambanglipuro.
# Retrieving Results for brae.
# Retrieving Results for pouebo.
# Retrieving Results for owando.
# Retrieving Results for limbang.
# Retrieving Results for lompoc.
# Retrieving Results for geraldton.
# Retrieving Results for quang ngai.
# Retrieving Results for mwene-ditu.
# Retrieving Results for cherskiy.
# Retrieving Results for makokou.
# Retrieving Results for olafsvik.
# Retrieving Results for te anau.
# Retrieving Results for grand gaube.
# Retrieving Results for manbij.
# Retrieving Results for taonan.
# Retrieving Results for lithakia.
# Retrieving Results for rajaldesar.
# Retrieving Results for kayes.
# Retrieving Results for la ronge.
# Retrieving Results for north myrtle beach.
# Retrieving Results for urubicha.
# Retrieving Results for sechura.
# Retrieving Results for hofn.
# Retrieving Results for sorong.
# Retrieving Results for kaohsiung.
# Retrieving Results for teeli.
# Retrieving Results for hit.
# Retrieving Results for arkhara.
# Retrieving Results for belokurikha.
# Retrieving Results for mandalgovi.
# Retrieving Results for humaita.
# Retrieving Results for salihorsk.
# Retrieving Results for nakhon ratchasima.
# Retrieving Results for matara.
# Retrieving Results for kaseda.
# Retrieving Results for aracaju.
# Retrieving Results for tuatapere.
# Retrieving Results for praia.
# Retrieving Results for clyde river.
# Retrieving Results for chapais.
# Retrieving Results for pozo colorado.
# Retrieving Results for launceston.
# Retrieving Results for ondangwa.
# Retrieving Results for awallan.
# Retrieving Results for gamba.
# Retrieving Results for buraydah.
# Retrieving Results for acapulco.
# Retrieving Results for mendi.
# Retrieving Results for esso.
# Retrieving Results for jumla.
# Retrieving Results for elko.
# Retrieving Results for pangkalanbuun.
# Retrieving Results for kawalu.
# Retrieving Results for sycow.
# Retrieving Results for palenque.
# Retrieving Results for walvis bay.
# Retrieving Results for krivosheino.
# Retrieving Results for maraa.
# Retrieving Results for tatarsk.
# Retrieving Results for kupino.
# Retrieving Results for hami.
# Retrieving Results for port keats.
# Retrieving Results for pangnirtung.
# Retrieving Results for port blair.
# Retrieving Results for kencong.
# Retrieving Results for cocorit.
# Retrieving Results for bontang.
# Retrieving Results for iwanai.
# Retrieving Results for maldonado.
# Retrieving Results for dongsheng.
# Retrieving Results for zalantun.
# Retrieving Results for constitucion.
# Retrieving Results for tikapur.
# Retrieving Results for santa isabel do rio negro.
# Retrieving Results for sandusky.
# Retrieving Results for biga.
# Retrieving Results for tasiilaq.
# Retrieving Results for mayor pablo lagerenza.
# Retrieving Results for dolny kubin.
# Retrieving Results for ayr.
# Retrieving Results for petropavlovsk-kamchatskiy.
# Retrieving Results for solnechnyy.
# Retrieving Results for manakara.
# Retrieving Results for liverpool.
# Retrieving Results for rio grande.
# Retrieving Results for nyurba.
# Retrieving Results for lakatoro.
# Retrieving Results for rudnyy.
# Retrieving Results for hovd.
# Retrieving Results for tezu.
# Retrieving Results for kankan.
# Retrieving Results for tabuk.
# Retrieving Results for kupang.
# Retrieving Results for kansanshi.
# Retrieving Results for katherine.
# Retrieving Results for avera.
# Retrieving Results for mogadishu.
# Retrieving Results for kununurra.
# Retrieving Results for yumen.
# Retrieving Results for oussouye.
# Retrieving Results for hereford.
# Retrieving Results for jiaonan.
# Retrieving Results for yarkovo.
# Retrieving Results for gizo.
# Retrieving Results for pemba.
# Retrieving Results for satuk.
# Retrieving Results for fairbanks.
# Retrieving Results for dhidhdhoo.
# Retrieving Results for ierapetra.
# Retrieving Results for muisne.
# Retrieving Results for clarence town.
# Retrieving Results for dali.
# Retrieving Results for cayenne.
# Retrieving Results for santa cruz de la palma.
# Retrieving Results for muros.
# Retrieving Results for port-gentil.
# Retrieving Results for la palma.
# Retrieving Results for hirara.
# Retrieving Results for woodstock.
# Retrieving Results for waconia.
# Retrieving Results for yining.
# Retrieving Results for odessa.
# Retrieving Results for aldergrove.
# Retrieving Results for stamford.
# Retrieving Results for la roche-sur-yon.
# Retrieving Results for vestmannaeyjar.
# Retrieving Results for witu.
# Retrieving Results for kenora.
# Retrieving Results for esperance.
# Retrieving Results for shaunavon.
# Retrieving Results for aldan.
# Retrieving Results for irbil.
# Retrieving Results for mamallapuram.
# Retrieving Results for robertsport.
# Retrieving Results for quatre cocos.
# Retrieving Results for tromso.
# Retrieving Results for flinders.
# Retrieving Results for harper.
# Retrieving Results for sao luiz gonzaga.
# Retrieving Results for paamiut.
# Retrieving Results for pacific grove.
# Retrieving Results for trairi.
# Retrieving Results for verkhniy lomov.
# Retrieving Results for hambantota.
# Retrieving Results for tumalaytay.
# Retrieving Results for wertheim.
# Retrieving Results for la cruz.
# Retrieving Results for singapore.
# Retrieving Results for cidreira.
# Retrieving Results for boa vista.
# Retrieving Results for cam ranh.
# Retrieving Results for banda aceh.
# Retrieving Results for hasaki.
# Retrieving Results for qeshm.
# Retrieving Results for juybar.
# Retrieving Results for troitskoye.
# Retrieving Results for sapa.
# Retrieving Results for saldanha.
# Retrieving Results for ihosy.
# Retrieving Results for lovozero.
# Retrieving Results for padang.
# Retrieving Results for sur.
# Retrieving Results for xifeng.
# Retrieving Results for athabasca.
# Retrieving Results for manicore.
# Retrieving Results for klichka.
# Retrieving Results for nuuk.
# Retrieving Results for axim.
# Retrieving Results for meulaboh.
# Retrieving Results for floro.
# Retrieving Results for cardston.
# Retrieving Results for acari.
# Retrieving Results for hualmay.
# Retrieving Results for kamloops.
# Retrieving Results for teofilo otoni.
# Retrieving Results for pisco.
# Retrieving Results for bibiani.
# Retrieving Results for marquette.
# Retrieving Results for westport.
# Retrieving Results for ust-koksa.
# Retrieving Results for porto-vecchio.
# Retrieving Results for mount pleasant.
# Retrieving Results for wagga wagga.
# Retrieving Results for jutai.
# Retrieving Results for beyneu.
# Retrieving Results for tirumullaivasal.
# Retrieving Results for goderich.
# Retrieving Results for calvinia.
# Retrieving Results for larsnes.
# Retrieving Results for ucluelet.
# Retrieving Results for simao dias.
# Retrieving Results for eldorado.
# Retrieving Results for santa vitoria do palmar.
# Retrieving Results for gayeri.
# Retrieving Results for zabid.
# Retrieving Results for andapa.
# Retrieving Results for tsumeb.
# Retrieving Results for diapaga.
# Retrieving Results for malakal.
# Retrieving Results for qandala.
# Retrieving Results for barra do garcas.
# Retrieving Results for baghdad.
# Retrieving Results for dwarka.
# Retrieving Results for vanimo.
# Retrieving Results for belomorsk.
# Retrieving Results for taoudenni.
# Retrieving Results for nassau.
# Retrieving Results for pontes e lacerda.
# Retrieving Results for vieques.
# Retrieving Results for sorland.
# Retrieving Results for beloha.
# Retrieving Results for eberndorf.
# Retrieving Results for tomatlan.
# Retrieving Results for sabzevar.
# Retrieving Results for constantine.
# Retrieving Results for marienburg.
# Retrieving Results for chadiza.
# Retrieving Results for jasidih.
# Retrieving Results for nanticoke.
# Retrieving Results for thinadhoo.
# Retrieving Results for hamilton.
# Retrieving Results for jermuk.
# Retrieving Results for sompeta.
# Retrieving Results for singkang.
# Retrieving Results for yenagoa.
# Retrieving Results for perth.
# Retrieving Results for bafilo.
# Retrieving Results for kagadi.
# Retrieving Results for alexandroupoli.
# Retrieving Results for darnah.
# Retrieving Results for hay river.
# Retrieving Results for kaeo.
# Retrieving Results for the valley.
# Retrieving Results for nome.
# Retrieving Results for belyy yar.
# Retrieving Results for elk city.
# Retrieving Results for nouakchott.
# Retrieving Results for tukrah.
# Retrieving Results for astoria.
# Retrieving Results for savelugu.
# Retrieving Results for smoky lake.
# Retrieving Results for cururupu.
# Retrieving Results for nhulunbuy.
# Retrieving Results for longyan.
# Retrieving Results for gamboula.
# Retrieving Results for itarema.
# Retrieving Results for netrakona.
# Retrieving Results for yaring.
# Retrieving Results for alekseyevsk.
# Retrieving Results for bria.
# Retrieving Results for rybnaya sloboda.
# Retrieving Results for tornio.
# Retrieving Results for acajutiba.
# Retrieving Results for ejido.
# Retrieving Results for zakamensk.
# Retrieving Results for longyearbyen.
# Retrieving Results for foumban.
# Retrieving Results for tampayan.
# Retrieving Results for rawson.
# Retrieving Results for qaqortoq.
# Retrieving Results for atar.
# Retrieving Results for knysna.
# Retrieving Results for tadine.
# Retrieving Results for chokwe.
# Retrieving Results for ruteng.
# Retrieving Results for mgandu.
# Retrieving Results for keflavik.
# Retrieving Results for villefranche-de-rouergue.
# Retrieving Results for chivilcoy.
# Retrieving Results for ilhabela.
# Retrieving Results for savannah bight.
# Retrieving Results for port lincoln.
# Retrieving Results for srivardhan.
# Retrieving Results for kalmunai.
# Retrieving Results for manono.
# Retrieving Results for kidal.
# Retrieving Results for maua.
# Retrieving Results for kologriv.
# Retrieving Results for kondoa.
# Retrieving Results for alta floresta.
# Retrieving Results for vardo.
# Retrieving Results for bugama.
# Retrieving Results for nemuro.
# Retrieving Results for huarmey.
# Retrieving Results for raudeberg.
# Retrieving Results for ban nahin.
# Retrieving Results for svetlaya.
# Retrieving Results for puerto del rosario.
# Retrieving Results for shimanovsk.
# Retrieving Results for udachnyy.
# Retrieving Results for hobyo.
# Retrieving Results for pau.
# Retrieving Results for pfullingen.
# Retrieving Results for port hueneme.
# Retrieving Results for nieuw amsterdam.
# Retrieving Results for bolshevik.
# Retrieving Results for mandurah.
# Retrieving Results for moses lake.
# Retrieving Results for talnakh.
# Retrieving Results for mingshui.
# Retrieving Results for ulaangom.
# Retrieving Results for vostok.
# Retrieving Results for moose factory.
# Retrieving Results for upington.
# Retrieving Results for pilar.
# Retrieving Results for touros.
# Retrieving Results for ramshir.
# Retrieving Results for sokoni.
# Retrieving Results for palaikastron.
# Retrieving Results for nadym.
# Retrieving Results for lombardia.
# Retrieving Results for qiongshan.
# Retrieving Results for santa ines.
# Retrieving Results for shubarkuduk.
# Retrieving Results for taltal.
# Retrieving Results for ancud.
# Retrieving Results for olkhovka.
# Retrieving Results for kingisepp.
# Retrieving Results for puerto madryn.
# Retrieving Results for mayumba.

# %%
# Export the city data into a .csv.
cities_df.to_csv(output_data_file, index=False)
# Display the DataFrame
cities_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         chuy -33.6971  -53.4616     70.09      96.0         2.0        6.24
# 1        vaini -21.2000 -175.2000     78.80      94.0        75.0        8.05
# 2       dikson  73.5069   80.5464    -16.96      90.0        69.0        7.07
# 3  provideniya  64.3833 -173.3000      7.03      84.0         1.0        2.01
# 4  yellowknife  62.4560 -114.3525    -24.00      75.0         1.0        3.44
#
#   Country          Date
# 0      UY  1.611454e+09
# 1      TO  1.611454e+09
# 2      RU  1.611454e+09
# 3      RU  1.611454e+09
# 4      CA  1.611454e+09

# %%
# Drop cities not found.
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
cities_df.replace('',np.nan)
clean_city_data = cities_df.dropna(how='any',inplace=False)
clean_city_data = clean_city_data.reset_index(drop=True)
clean_city_data.to_csv(output_data_file, index=False)

# %%
# Inspect the data and remove the cities where the humidity > 100%.
# Get the indices of cities that have humidity over 100%.
clean_city_data.loc[clean_city_data['Humidity'] > 100]
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
# Describe cleaned city data.
clean_city_data.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  587.000000  587.000000  587.000000  587.000000  587.000000  587.000000
# mean    19.334564   15.903780   49.670784   75.000000   56.483816    7.510068
# std     32.983042   88.097704   32.223420   18.904015   40.007009    5.879591
# min    -54.800000 -179.166700  -51.990000   10.000000    0.000000    0.450000
# 25%     -8.026500  -59.695350   30.200000   67.000000   15.500000    3.440000
# 50%     21.461200   19.303400   61.110000   80.000000   75.000000    5.750000
# 75%     47.776350   91.053500   75.245000   88.000000   98.000000    9.395000
# max     78.218600  178.416700  102.000000  100.000000  100.000000   37.960000
#
#                Date
# count  5.870000e+02
# mean   1.611454e+09
# std    6.706009e+01
# min    1.611454e+09
# 25%    1.611454e+09
# 50%    1.611454e+09
# 75%    1.611454e+09
# max    1.611454e+09

# %%
# Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# Save the plotted figures as .pngs.

# %%
# Latitude vs. Temperature Plot
clean_city_data.plot(kind="scatter",x="Lat",y="Max Temp",title="City Latitude vs. Max Temperature (23Jan2021)",grid=True)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.savefig("output_data/lat_temp_scatter.png")
plt.show()

# %%
# Latitude vs. Humidity Plot
clean_city_data.plot(kind="scatter",x="Lat",y="Humidity",title="City Latitude vs. Humidity (23Jan2021)",grid=True)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("output_data/lat_humid_scatter.png")
plt.show()

# %%
# Latitude vs. Cloudiness Plot
clean_city_data.plot(kind="scatter",x="Lat",y="Cloudiness",title="City Latitude vs. Cloudiness (23Jan2021)",grid=True)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("output_data/lat_cloud_scatter.png")
plt.show()

# %%
# Latitude vs. Wind Speed Plot
clean_city_data.plot(kind="scatter",x="Lat",y="Wind Speed",title="City Latitude vs. Wind Speed (23Jan2021)",grid=True)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("output_data/lat_wind_scatter.png")
plt.show()

# %%
# Define cities in Northern Hemisphere
north_cities = clean_city_data.loc[clean_city_data['Lat'] > 0]

# Regression
x_nvalues = north_cities["Lat"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_nvalues,north_cities["Max Temp"])
regress_values = x_nvalues * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Northern Hemisphere - Max Temp vs. Latitude Linear Regression
north_cities.plot(kind="scatter",x="Lat",y="Max Temp",title="Northern Hemishphere - City Latitude vs. Max Temperature (23Jan2021)",grid=True)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.plot(x_nvalues,regress_values,"r-")
plt.annotate(line_eq,(0,-40),fontsize=15,color="red")
plt.savefig("output_data/north_lat_temp_regression.png")
plt.show()
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: -0.8506050601880989

# %%
# Define cities in Southern Hemisphere
south_cities = clean_city_data.loc[clean_city_data['Lat'] < 0]

# Regression
x_svalues = south_cities["Lat"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_svalues,south_cities["Max Temp"])
regress_values = x_svalues * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Southern Hemisphere - Max Temp vs. Latitude Linear Regression
south_cities.plot(kind="scatter",x="Lat",y="Max Temp",title="Southern Hemishphere - City Latitude vs. Max Temperature (23Jan2021)",grid=True)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.plot(x_svalues,regress_values,"r-")
plt.annotate(line_eq,(-50,90),fontsize=15,color="red")
plt.savefig("output_data/south_lat_temp_regression.png")
plt.show()
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: 0.32950602558509556

# %%
# Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_nvalues,north_cities["Humidity"])
regress_values = x_nvalues * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
north_cities.plot(kind="scatter",x="Lat",y="Humidity",title="Northern Hemishphere - City Latitude vs. Humidity (23Jan2021)",grid=True)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.plot(x_nvalues,regress_values,"r-")
plt.annotate(line_eq,(40,30),fontsize=15,color="red")
plt.savefig("output_data/north_lat_humid_regression.png")
plt.show()
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: 0.30163001850815463

# %%
# Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_svalues,south_cities["Humidity"])
regress_values = x_svalues * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
south_cities.plot(kind="scatter",x="Lat",y="Humidity",title="Southern Hemishphere - City Latitude vs. Humidity (23Jan2021)",grid=True)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.plot(x_svalues,regress_values,"r-")
plt.annotate(line_eq,(-30,40),fontsize=15,color="red")
plt.savefig("output_data/south_lat_humid_regression.png")
plt.show()
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: 0.38625498542830156

# %%
# Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_nvalues,north_cities["Cloudiness"])
regress_values = x_nvalues * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
north_cities.plot(kind="scatter",x="Lat",y="Cloudiness",title="Northern Hemishphere - City Latitude vs. Cloudiness (23Jan2021)",grid=True)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.plot(x_nvalues,regress_values,"r-")
plt.annotate(line_eq,(5,60),fontsize=15,color="red")
plt.savefig("output_data/north_lat_cloud_regression.png")
plt.show()
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: 0.19242854047237268

# %%
# Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_svalues,south_cities["Cloudiness"])
regress_values = x_svalues * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
south_cities.plot(kind="scatter",x="Lat",y="Cloudiness",title="Southern Hemishphere - City Latitude vs. Cloudiness (23Jan2021)",grid=True)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.plot(x_svalues,regress_values,"r-")
plt.annotate(line_eq,(-55,60),fontsize=15,color="red")
plt.savefig("output_data/south_lat_cloud_regression.png")
plt.show()
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: 0.3369039481824591

# %%
# Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_nvalues,north_cities["Wind Speed"])
regress_values = x_nvalues * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
north_cities.plot(kind="scatter",x="Lat",y="Wind Speed",title="Northern Hemishphere - City Latitude vs. Wind Speed (23Jan2021)",grid=True)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph))")
plt.plot(x_nvalues,regress_values,"r-")
plt.annotate(line_eq,(0,25),fontsize=15,color="red")
plt.savefig("output_data/north_lat_wind_regression.png")
plt.show()
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: 0.14332219755436923

# %%
# Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_svalues,south_cities["Wind Speed"])
regress_values = x_svalues * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
south_cities.plot(kind="scatter",x="Lat",y="Wind Speed",title="Southern Hemishphere - City Latitude vs. Wind Speed (23Jan2021)",grid=True)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph))")
plt.plot(x_svalues,regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.savefig("output_data/south_lat_wind_regression.png")
plt.show()
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: -0.4844629345361707
